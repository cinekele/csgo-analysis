# %% [markdown]
# # Załadowanie paczek

# %%
import pandas as pd
from sqlalchemy import create_engine
from tqdm import tqdm

# %% [markdown]
# ## Pobranie danych z bazy

# %%
db_con = create_engine('mysql+mysqlconnector://root:password@localhost/CSGOAnalysis?allow_local_infile=1')
db_con
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost/CSGOAnalysis?allow_local_infile=1)

# %%
def get_summed_columns(columns):
    both_teams = [
        f"{team}Player_1_{column} + {team}Player_2_{column} + {team}Player_3_{column} + {team}Player_4_{column} + {team}Player_5_{column} as {team}_{column}"
        for column in columns
            for team in ["ct", "t"]
    ]
    team_specific = [
        f"{team}Player_1_{column} + {team}Player_2_{column} + {team}Player_3_{column} + {team}Player_4_{column} + {team}Player_5_{column} as {team}_{column}"
            for team, column in [("ct", "hasDefuse"), ("t", "hasBomb"), ("ct", "isDefusing"), ("t", "isPlanting")]
    ]
    return both_teams + team_specific

get_summed_columns(["hp", "armor", "hasHelmet", "DecoyGrenade", "Flashbang", "HEGrenade", "SmokeGrenade", "fireGrenades", "isBlinded"])
# Out:
# ['ctPlayer_1_hp + ctPlayer_2_hp + ctPlayer_3_hp + ctPlayer_4_hp + ctPlayer_5_hp as ct_hp',
#  'tPlayer_1_hp + tPlayer_2_hp + tPlayer_3_hp + tPlayer_4_hp + tPlayer_5_hp as t_hp',
#  'ctPlayer_1_armor + ctPlayer_2_armor + ctPlayer_3_armor + ctPlayer_4_armor + ctPlayer_5_armor as ct_armor',
#  'tPlayer_1_armor + tPlayer_2_armor + tPlayer_3_armor + tPlayer_4_armor + tPlayer_5_armor as t_armor',
#  'ctPlayer_1_hasHelmet + ctPlayer_2_hasHelmet + ctPlayer_3_hasHelmet + ctPlayer_4_hasHelmet + ctPlayer_5_hasHelmet as ct_hasHelmet',
#  'tPlayer_1_hasHelmet + tPlayer_2_hasHelmet + tPlayer_3_hasHelmet + tPlayer_4_hasHelmet + tPlayer_5_hasHelmet as t_hasHelmet',
#  'ctPlayer_1_DecoyGrenade + ctPlayer_2_DecoyGrenade + ctPlayer_3_DecoyGrenade + ctPlayer_4_DecoyGrenade + ctPlayer_5_DecoyGrenade as ct_DecoyGrenade',
#  'tPlayer_1_DecoyGrenade + tPlayer_2_DecoyGrenade + tPlayer_3_DecoyGrenade + tPlayer_4_DecoyGrenade + tPlayer_5_DecoyGrenade as t_DecoyGrenade',
#  'ctPlayer_1_Flashbang + ctPlayer_2_Flashbang + ctPlayer_3_Flashbang + ctPlayer_4_Flashbang + ctPlayer_5_Flashbang as ct_Flashbang',
#  'tPlayer_1_Flashbang + tPlayer_2_Flashbang + tPlayer_3_Flashbang + tPlayer_4_Flashbang + tPlayer_5_Flashbang as t_Flashbang',
#  'ctPlayer_1_HEGrenade + ctPlayer_2_HEGrenade + ctPlayer_3_HEGrenade + ctPlayer_4_HEGrenade + ctPlayer_5_HEGrenade as ct_HEGrenade',
#  'tPlayer_1_HEGrenade + tPlayer_2_HEGrenade + tPlayer_3_HEGrenade + tPlayer_4_HEGrenade + tPlayer_5_HEGrenade as t_HEGrenade',
#  'ctPlayer_1_SmokeGrenade + ctPlayer_2_SmokeGrenade + ctPlayer_3_SmokeGrenade + ctPlayer_4_SmokeGrenade + ctPlayer_5_SmokeGrenade as ct_SmokeGrenade',
#  'tPlayer_1_SmokeGrenade + tPlayer_2_SmokeGrenade + tPlayer_3_SmokeGrenade + tPlayer_4_SmokeGrenade + tPlayer_5_SmokeGrenade as t_SmokeGrenade',
#  'ctPlayer_1_fireGrenades + ctPlayer_2_fireGrenades + ctPlayer_3_fireGrenades + ctPlayer_4_fireGrenades + ctPlayer_5_fireGrenades as ct_fireGrenades',
#  'tPlayer_1_fireGrenades + tPlayer_2_fireGrenades + tPlayer_3_fireGrenades + tPlayer_4_fireGrenades + tPlayer_5_fireGrenades as t_fireGrenades',
#  'ctPlayer_1_isBlinded + ctPlayer_2_isBlinded + ctPlayer_3_isBlinded + ctPlayer_4_isBlinded + ctPlayer_5_isBlinded as ct_isBlinded',
#  'tPlayer_1_isBlinded + tPlayer_2_isBlinded + tPlayer_3_isBlinded + tPlayer_4_isBlinded + tPlayer_5_isBlinded as t_isBlinded',
#  'ctPlayer_1_hasDefuse + ctPlayer_2_hasDefuse + ctPlayer_3_hasDefuse + ctPlayer_4_hasDefuse + ctPlayer_5_hasDefuse as ct_hasDefuse',
#  'tPlayer_1_hasBomb + tPlayer_2_hasBomb + tPlayer_3_hasBomb + tPlayer_4_hasBomb + tPlayer_5_hasBomb as t_hasBomb',
#  'ctPlayer_1_isDefusing + ctPlayer_2_isDefusing + ctPlayer_3_isDefusing + ctPlayer_4_isDefusing + ctPlayer_5_isDefusing as ct_isDefusing',
#  'tPlayer_1_isPlanting + tPlayer_2_isPlanting + tPlayer_3_isPlanting + tPlayer_4_isPlanting + tPlayer_5_isPlanting as t_isPlanting']

# %%
def get_position_columns():
    players = [f"{team}Player_{i}_{pos}"
        for team in ["ct", "t"]
            for i in range(1, 6)
                for pos in ["x", "y","z"]
    ]
    bomb = [f"bomb_{pos}" for pos in ["x", "y","z"]]
    return players + bomb
get_position_columns()
# Out:
# ['ctPlayer_1_x',
#  'ctPlayer_1_y',
#  'ctPlayer_1_z',
#  'ctPlayer_2_x',
#  'ctPlayer_2_y',
#  'ctPlayer_2_z',
#  'ctPlayer_3_x',
#  'ctPlayer_3_y',
#  'ctPlayer_3_z',
#  'ctPlayer_4_x',
#  'ctPlayer_4_y',
#  'ctPlayer_4_z',
#  'ctPlayer_5_x',
#  'ctPlayer_5_y',
#  'ctPlayer_5_z',
#  'tPlayer_1_x',
#  'tPlayer_1_y',
#  'tPlayer_1_z',
#  'tPlayer_2_x',
#  'tPlayer_2_y',
#  'tPlayer_2_z',
#  'tPlayer_3_x',
#  'tPlayer_3_y',
#  'tPlayer_3_z',
#  'tPlayer_4_x',
#  'tPlayer_4_y',
#  'tPlayer_4_z',
#  'tPlayer_5_x',
#  'tPlayer_5_y',
#  'tPlayer_5_z',
#  'bomb_x',
#  'bomb_y',
#  'bomb_z']

# %%
def get_additional_columns(cols):
    additional_cols = [
        f"{team}Player_{i}_{col}"
        for team in ["ct", "t"]
            for i in range(1, 6)
                for col in cols
    ]
    return additional_cols
get_additional_columns(["spotters", "activeWeapon", "mainWeapon", "secondaryWeapon", "isAlive", "lastPlaceName", "ID"])
# Out:
# ['ctPlayer_1_spotters',
#  'ctPlayer_1_activeWeapon',
#  'ctPlayer_1_mainWeapon',
#  'ctPlayer_1_secondaryWeapon',
#  'ctPlayer_1_isAlive',
#  'ctPlayer_1_lastPlaceName',
#  'ctPlayer_1_ID',
#  'ctPlayer_2_spotters',
#  'ctPlayer_2_activeWeapon',
#  'ctPlayer_2_mainWeapon',
#  'ctPlayer_2_secondaryWeapon',
#  'ctPlayer_2_isAlive',
#  'ctPlayer_2_lastPlaceName',
#  'ctPlayer_2_ID',
#  'ctPlayer_3_spotters',
#  'ctPlayer_3_activeWeapon',
#  'ctPlayer_3_mainWeapon',
#  'ctPlayer_3_secondaryWeapon',
#  'ctPlayer_3_isAlive',
#  'ctPlayer_3_lastPlaceName',
#  'ctPlayer_3_ID',
#  'ctPlayer_4_spotters',
#  'ctPlayer_4_activeWeapon',
#  'ctPlayer_4_mainWeapon',
#  'ctPlayer_4_secondaryWeapon',
#  'ctPlayer_4_isAlive',
#  'ctPlayer_4_lastPlaceName',
#  'ctPlayer_4_ID',
#  'ctPlayer_5_spotters',
#  'ctPlayer_5_activeWeapon',
#  'ctPlayer_5_mainWeapon',
#  'ctPlayer_5_secondaryWeapon',
#  'ctPlayer_5_isAlive',
#  'ctPlayer_5_lastPlaceName',
#  'ctPlayer_5_ID',
#  'tPlayer_1_spotters',
#  'tPlayer_1_activeWeapon',
#  'tPlayer_1_mainWeapon',
#  'tPlayer_1_secondaryWeapon',
#  'tPlayer_1_isAlive',
#  'tPlayer_1_lastPlaceName',
#  'tPlayer_1_ID',
#  'tPlayer_2_spotters',
#  'tPlayer_2_activeWeapon',
#  'tPlayer_2_mainWeapon',
#  'tPlayer_2_secondaryWeapon',
#  'tPlayer_2_isAlive',
#  'tPlayer_2_lastPlaceName',
#  'tPlayer_2_ID',
#  'tPlayer_3_spotters',
#  'tPlayer_3_activeWeapon',
#  'tPlayer_3_mainWeapon',
#  'tPlayer_3_secondaryWeapon',
#  'tPlayer_3_isAlive',
#  'tPlayer_3_lastPlaceName',
#  'tPlayer_3_ID',
#  'tPlayer_4_spotters',
#  'tPlayer_4_activeWeapon',
#  'tPlayer_4_mainWeapon',
#  'tPlayer_4_secondaryWeapon',
#  'tPlayer_4_isAlive',
#  'tPlayer_4_lastPlaceName',
#  'tPlayer_4_ID',
#  'tPlayer_5_spotters',
#  'tPlayer_5_activeWeapon',
#  'tPlayer_5_mainWeapon',
#  'tPlayer_5_secondaryWeapon',
#  'tPlayer_5_isAlive',
#  'tPlayer_5_lastPlaceName',
#  'tPlayer_5_ID']

# %%
def build_query():
    selected_columns = get_summed_columns(["hp", "armor", "hasHelmet", "DecoyGrenade", "Flashbang", "HEGrenade", "SmokeGrenade", "fireGrenades", "isBlinded"]) + \
                get_position_columns() + get_additional_columns(["spotters", "activeWeapon", "mainWeapon", "secondaryWeapon", "isAlive", "lastPlaceName", "ID"])
    selected_columns_query = ", ".join(selected_columns)
    query = """SELECT g.filename, g.mapName, r.ctBuyType, r.tBuyType, r.winningSide, f.matchID, f.roundNum,
                    f.seconds, f.ctAlivePlayers, f.ctEqVal, f.tAlivePlayers, f.tEqVal, f.bombsite,
            """ + \
            selected_columns_query + \
            """ FROM frame f
                INNER JOIN round r ON f.matchID=r.matchID AND f.roundNum=r.roundNum
                INNER JOIN game g ON g.ID=f.matchID
                WHERE f.tick < r.endTickCorrect AND (g.filename like "IEM-Katowice%" OR g.filename like "BLAST-Premier-Spring-Final-2022-%")
            """
    return query

# %%
query = build_query()
with db_con.connect() as connection:
    states = pd.read_sql(query, con=connection)
states
# Out:
#                                                  filename     mapName  \
# 0       BLAST-Premier-Spring-Final-2022-ence-vs-big-bo...   de_mirage
# 1       BLAST-Premier-Spring-Final-2022-ence-vs-big-bo...   de_mirage
# 2       BLAST-Premier-Spring-Final-2022-ence-vs-big-bo...   de_mirage
# 3       BLAST-Premier-Spring-Final-2022-ence-vs-big-bo...   de_mirage
# 4       BLAST-Premier-Spring-Final-2022-ence-vs-big-bo...   de_mirage
# ...                                                   ...         ...
# 620387           IEM-Katowice-2022-vitality-vs-gambit-bo3  de_inferno
# 620388           IEM-Katowice-2022-vitality-vs-gambit-bo3  de_inferno
# 620389           IEM-Katowice-2022-vitality-vs-gambit-bo3  de_inferno
# 620390           IEM-Katowice-2022-vitality-vs-gambit-bo3  de_inferno
# 620391           IEM-Katowice-2022-vitality-vs-gambit-bo3  de_inferno
#
#        ctBuyType  tBuyType winningSide  matchID  roundNum   seconds  \
# 0       Full Eco  Full Eco          CT        1         1  0.148438
# 1       Full Eco  Full Eco          CT        1         1  0.398438
# 2       Full Eco  Full Eco          CT        1         1  0.648438
# 3       Full Eco  Full Eco          CT        1         1  0.898438
# 4       Full Eco  Full Eco          CT        1         1  1.148438
# ...          ...       ...         ...      ...       ...       ...
# 620387  Full Buy  Full Buy           T      364        28  7.062500
# 620388  Full Buy  Full Buy           T      364        28  7.312500
# 620389  Full Buy  Full Buy           T      364        28  7.562500
# 620390  Full Buy  Full Buy           T      364        28  7.812500
# 620391  Full Buy  Full Buy           T      364        28  8.062500
#
#         ctAlivePlayers  ctEqVal  ...  tPlayer_4_isAlive  \
# 0                    5     3700  ...                  1
# 1                    5     3700  ...                  1
# 2                    5     3700  ...                  1
# 3                    5     3700  ...                  1
# 4                    5     3700  ...                  1
# ...                ...      ...  ...                ...
# 620387               1    30100  ...                  0
# 620388               1    30100  ...                  0
# 620389               1    30100  ...                  0
# 620390               1    30100  ...                  0
# 620391               1    30100  ...                  0
#
#         tPlayer_4_lastPlaceName tPlayer_4_ID  tPlayer_5_spotters  \
# 0                        TSpawn            6                  []
# 1                        TSpawn            6                  []
# 2                        TSpawn            6                  []
# 3                        TSpawn            6                  []
# 4                        TSpawn            6                  []
# ...                         ...          ...                 ...
# 620387                BombsiteA          241                  []
# 620388                BombsiteA          241                  []
# 620389                BombsiteA          241                  []
# 620390                BombsiteA          241                  []
# 620391                BombsiteA          241                  []
#
#         tPlayer_5_activeWeapon  tPlayer_5_mainWeapon  \
# 0                        Knife              Glock-18
# 1                        Knife              Glock-18
# 2                        Knife              Glock-18
# 3                        Knife              Glock-18
# 4                        Knife              Glock-18
# ...                        ...                   ...
# 620387                   AK-47                 AK-47
# 620388                   AK-47                 AK-47
# 620389                   AK-47                 AK-47
# 620390                   AK-47                 AK-47
# 620391                   AK-47                 AK-47
#
#         tPlayer_5_secondaryWeapon  tPlayer_5_isAlive  tPlayer_5_lastPlaceName  \
# 0                        Glock-18                  1                   TSpawn
# 1                        Glock-18                  1                   TSpawn
# 2                        Glock-18                  1                   TSpawn
# 3                        Glock-18                  1                   TSpawn
# 4                        Glock-18                  1                   TSpawn
# ...                           ...                ...                      ...
# 620387                   Glock-18                  1                BombsiteA
# 620388                   Glock-18                  1                BombsiteA
# 620389                   Glock-18                  1                BombsiteA
# 620390                   Glock-18                  1                BombsiteA
# 620391                   Glock-18                  1                BombsiteA
#
#         tPlayer_5_ID
# 0                  9
# 1                  9
# 2                  9
# 3                  9
# 4                  9
# ...              ...
# 620387           242
# 620388           242
# 620389           242
# 620390           242
# 620391           242
#
# [620392 rows x 138 columns]

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620392 entries, 0 to 620391
# Columns: 138 entries, filename to tPlayer_5_ID
# dtypes: float64(34), int64(48), object(56)
# memory usage: 653.2+ MB

# %%
import gc
gc.collect()
# Out:
# 0

# %%
states.to_parquet("data/states_test.parquet")
