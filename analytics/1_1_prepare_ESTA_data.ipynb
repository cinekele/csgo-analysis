# %% [markdown]
# # Preprocess

# %%
import os
import pandas as pd
import numpy as np
import lzma
import json

import random

from tqdm import tqdm
from awpy.data import PLACE_DIST_MATRIX, NAV
from awpy.analytics.nav import find_closest_area

# %%
path = r"C:\Users\Piotrek\Documents\Inzynierka\esta-v1.0\pnxenopoulos-esta-f684ccf\data" 
online_files = os.listdir(os.path.join(path, "online"))
online_files = [os.path.join(path, "online", f) for f in online_files] 
lan_files = os.listdir(os.path.join(path, "lan"))
lan_files = [os.path.join(path, "lan", f) for f in lan_files]
demo_files = online_files + lan_files
len(demo_files)
# Out:
# 1558

# %%
def read_parsed_demo(filename):
    with lzma.LZMAFile(filename, "rb") as f:
        d = json.load(f)
    return d

# %%
def get_team_data(frame, team, mapping):
        team_frame = frame[team]
        team_data = {}
        team_data[team + 'Name'] = team_frame['teamName']
        team_data[team + 'EqVal'] = team_frame['teamEqVal']
        team_data[team + 'AlivePlayers'] = team_frame['alivePlayers']
        team_data[team + 'TotalUtility'] = team_frame['totalUtility']

        for player in team_frame['players']:
            mapped_player = mapping[player['steamID']]
            team_data[f"{team}{mapped_player}_ID"] = player['steamID']
            for key_player in player:
                if key_player not in ['inventory', 'steamID', 'name', 'team', 'side', 'flashGrenades', 'smokeGrenades', 
                                     'heGrenades', 'fireGrenades', 'totalUtility']:
                    team_data[f'{team}{mapped_player}_{key_player}'] = player[key_player]
                elif key_player == 'inventory':
                    team_data[f"{team}{mapped_player}_SmokeGrenade"] = 0
                    team_data[f"{team}{mapped_player}_Flashbang"] = 0
                    team_data[f"{team}{mapped_player}_DecoyGrenade"] = 0
                    team_data[f"{team}{mapped_player}_fireGrenades"] = 0
                    team_data[f"{team}{mapped_player}_HEGrenade"] = 0
                    if player[key_player] is None:
                        team_data[f'{team}{mapped_player}_mainWeapon'] = ''
                        team_data[f'{team}{mapped_player}_secondaryWeapon'] = ''
                    else:
                        for weapon in player[key_player]:
                            if weapon['weaponClass'] == 'Pistols':
                                team_data[f'{team}{mapped_player}_secondaryWeapon'] = weapon['weaponName']
                            elif weapon['weaponClass'] == 'Grenade':
                                if weapon['weaponName'] in {"Molotov", "Incendiary Grenade"}:
                                    team_data[f"{team}{mapped_player}_fireGrenades"] = weapon['ammoInMagazine'] +\
                                        weapon['ammoInReserve']
                                else:
                                    team_data[f"{team}{mapped_player}_{weapon['weaponName'].replace(' ', '')}"] =\
                                        weapon['ammoInMagazine'] + weapon['ammoInReserve']
                            else:
                                team_data[f'{team}{mapped_player}_mainWeapon'] = weapon['weaponName']
                        if f'{team}{mapped_player}_mainWeapon' not in team_data and\
                                f'{team}{mapped_player}_secondaryWeapon' not in team_data:
                            team_data[f'{team}{mapped_player}_mainWeapon'] = ''
                        elif f'{team}{mapped_player}_mainWeapon' not in team_data:
                            team_data[f'{team}{mapped_player}_mainWeapon'] =\
                                team_data[f'{team}{mapped_player}_secondaryWeapon']
        return team_data

def get_frame_data(frame, mapping):
        frame_data = {**get_team_data(frame, 'ct', mapping), 
                      **get_team_data(frame, 't', mapping)}
        frame_data['bombPlanted'] = frame['bombPlanted']
        frame_data['bombsite'] = frame['bombsite']
        frame_data['tick'] = frame['tick']
        frame_data['seconds'] = frame['seconds']
        frame_data['clockTime'] = frame['clockTime']
        bomb_data = frame['bomb']
        for key in bomb_data:
            frame_data[f"bomb_{key}"] = bomb_data[key]
        return frame_data

def create_mapping(round_):
    ct_players = round_['ctSide']
    map_steam_id = {}
    for i, player in enumerate(ct_players['players']):
        map_steam_id[player['steamID']] = f'Player_{i + 1}'

    t_players = round_['tSide']
    for i, player in enumerate(t_players['players']):
        map_steam_id[player['steamID']] = f'Player_{i + 1}'

    return map_steam_id

def get_match_data(data):
    data_list = []
    round_ = data['gameRounds'][1] if data['gameRounds'][0]['ctSide']['players'] is None else data['gameRounds'][0]
    mapping = create_mapping(round_)
    for round_ in data['gameRounds']:
        for frame in round_['frames']:
            if (frame["ct"]["players"] is not None) & (frame["t"]["players"] is not None) & (frame["clockTime"] != "00:00") & (frame["t"]["alivePlayers"] >= 0) & (frame["ct"]["alivePlayers"] >= 1):
                if (len(frame["ct"]["players"]) == 5) & (len(frame["t"]["players"]) == 5):
                    converted_vector = get_frame_data(frame, mapping)
                    converted_vector['roundNum'] = round_['roundNum']
                    converted_vector['winningSide'] = round_['winningSide']
                    data_list.append(converted_vector)
    res = pd.DataFrame(data_list)
    res['matchName'] = data['matchName']
    res['mapName'] = data['mapName']
    res.fillna(method='ffill', inplace=True)
    return res

# %%
def process_demo(filename):
    parsed_demo = read_parsed_demo(filename)
    match_df = get_match_data(parsed_demo)
    return match_df

all_matches = []
for f in tqdm(demo_files):
    parsed_demo = read_parsed_demo(f)
    match_df = get_match_data(parsed_demo)
    all_matches.append(match_df)
len(all_matches)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1558/1558 [1:10:26<00:00,  2.71s/it]
# 1558

# %%
states = pd.concat(all_matches)
states.to_parquet("data/states_ESTA_all.parquet")

# %%
del all_matches

# %% [markdown]
# # Read parquet

# %%
states = pd.read_parquet("data/states_ESTA_all.parquet")

# %%
states.columns.tolist()
# Out:
# ['ctName',
#  'ctEqVal',
#  'ctAlivePlayers',
#  'ctTotalUtility',
#  'ctPlayer_1_ID',
#  'ctPlayer_1_x',
#  'ctPlayer_1_y',
#  'ctPlayer_1_z',
#  'ctPlayer_1_velocityX',
#  'ctPlayer_1_velocityY',
#  'ctPlayer_1_velocityZ',
#  'ctPlayer_1_viewX',
#  'ctPlayer_1_viewY',
#  'ctPlayer_1_hp',
#  'ctPlayer_1_armor',
#  'ctPlayer_1_activeWeapon',
#  'ctPlayer_1_isAlive',
#  'ctPlayer_1_isBlinded',
#  'ctPlayer_1_isAirborne',
#  'ctPlayer_1_isDucking',
#  'ctPlayer_1_isDuckingInProgress',
#  'ctPlayer_1_isUnDuckingInProgress',
#  'ctPlayer_1_isDefusing',
#  'ctPlayer_1_isPlanting',
#  'ctPlayer_1_isReloading',
#  'ctPlayer_1_isInBombZone',
#  'ctPlayer_1_isInBuyZone',
#  'ctPlayer_1_isStanding',
#  'ctPlayer_1_isScoped',
#  'ctPlayer_1_isWalking',
#  'ctPlayer_1_isUnknown',
#  'ctPlayer_1_SmokeGrenade',
#  'ctPlayer_1_Flashbang',
#  'ctPlayer_1_DecoyGrenade',
#  'ctPlayer_1_fireGrenades',
#  'ctPlayer_1_HEGrenade',
#  'ctPlayer_1_secondaryWeapon',
#  'ctPlayer_1_mainWeapon',
#  'ctPlayer_1_spotters',
#  'ctPlayer_1_equipmentValue',
#  'ctPlayer_1_equipmentValueFreezetimeEnd',
#  'ctPlayer_1_equipmentValueRoundStart',
#  'ctPlayer_1_cash',
#  'ctPlayer_1_cashSpendThisRound',
#  'ctPlayer_1_cashSpendTotal',
#  'ctPlayer_1_hasHelmet',
#  'ctPlayer_1_hasDefuse',
#  'ctPlayer_1_hasBomb',
#  'ctPlayer_1_ping',
#  'ctPlayer_1_zoomLevel',
#  'ctPlayer_5_ID',
#  'ctPlayer_5_x',
#  'ctPlayer_5_y',
#  'ctPlayer_5_z',
#  'ctPlayer_5_velocityX',
#  'ctPlayer_5_velocityY',
#  'ctPlayer_5_velocityZ',
#  'ctPlayer_5_viewX',
#  'ctPlayer_5_viewY',
#  'ctPlayer_5_hp',
#  'ctPlayer_5_armor',
#  'ctPlayer_5_activeWeapon',
#  'ctPlayer_5_isAlive',
#  'ctPlayer_5_isBlinded',
#  'ctPlayer_5_isAirborne',
#  'ctPlayer_5_isDucking',
#  'ctPlayer_5_isDuckingInProgress',
#  'ctPlayer_5_isUnDuckingInProgress',
#  'ctPlayer_5_isDefusing',
#  'ctPlayer_5_isPlanting',
#  'ctPlayer_5_isReloading',
#  'ctPlayer_5_isInBombZone',
#  'ctPlayer_5_isInBuyZone',
#  'ctPlayer_5_isStanding',
#  'ctPlayer_5_isScoped',
#  'ctPlayer_5_isWalking',
#  'ctPlayer_5_isUnknown',
#  'ctPlayer_5_SmokeGrenade',
#  'ctPlayer_5_Flashbang',
#  'ctPlayer_5_DecoyGrenade',
#  'ctPlayer_5_fireGrenades',
#  'ctPlayer_5_HEGrenade',
#  'ctPlayer_5_secondaryWeapon',
#  'ctPlayer_5_mainWeapon',
#  'ctPlayer_5_spotters',
#  'ctPlayer_5_equipmentValue',
#  'ctPlayer_5_equipmentValueFreezetimeEnd',
#  'ctPlayer_5_equipmentValueRoundStart',
#  'ctPlayer_5_cash',
#  'ctPlayer_5_cashSpendThisRound',
#  'ctPlayer_5_cashSpendTotal',
#  'ctPlayer_5_hasHelmet',
#  'ctPlayer_5_hasDefuse',
#  'ctPlayer_5_hasBomb',
#  'ctPlayer_5_ping',
#  'ctPlayer_5_zoomLevel',
#  'ctPlayer_2_ID',
#  'ctPlayer_2_x',
#  'ctPlayer_2_y',
#  'ctPlayer_2_z',
#  'ctPlayer_2_velocityX',
#  'ctPlayer_2_velocityY',
#  'ctPlayer_2_velocityZ',
#  'ctPlayer_2_viewX',
#  'ctPlayer_2_viewY',
#  'ctPlayer_2_hp',
#  'ctPlayer_2_armor',
#  'ctPlayer_2_activeWeapon',
#  'ctPlayer_2_isAlive',
#  'ctPlayer_2_isBlinded',
#  'ctPlayer_2_isAirborne',
#  'ctPlayer_2_isDucking',
#  'ctPlayer_2_isDuckingInProgress',
#  'ctPlayer_2_isUnDuckingInProgress',
#  'ctPlayer_2_isDefusing',
#  'ctPlayer_2_isPlanting',
#  'ctPlayer_2_isReloading',
#  'ctPlayer_2_isInBombZone',
#  'ctPlayer_2_isInBuyZone',
#  'ctPlayer_2_isStanding',
#  'ctPlayer_2_isScoped',
#  'ctPlayer_2_isWalking',
#  'ctPlayer_2_isUnknown',
#  'ctPlayer_2_SmokeGrenade',
#  'ctPlayer_2_Flashbang',
#  'ctPlayer_2_DecoyGrenade',
#  'ctPlayer_2_fireGrenades',
#  'ctPlayer_2_HEGrenade',
#  'ctPlayer_2_secondaryWeapon',
#  'ctPlayer_2_mainWeapon',
#  'ctPlayer_2_spotters',
#  'ctPlayer_2_equipmentValue',
#  'ctPlayer_2_equipmentValueFreezetimeEnd',
#  'ctPlayer_2_equipmentValueRoundStart',
#  'ctPlayer_2_cash',
#  'ctPlayer_2_cashSpendThisRound',
#  'ctPlayer_2_cashSpendTotal',
#  'ctPlayer_2_hasHelmet',
#  'ctPlayer_2_hasDefuse',
#  'ctPlayer_2_hasBomb',
#  'ctPlayer_2_ping',
#  'ctPlayer_2_zoomLevel',
#  'ctPlayer_3_ID',
#  'ctPlayer_3_x',
#  'ctPlayer_3_y',
#  'ctPlayer_3_z',
#  'ctPlayer_3_velocityX',
#  'ctPlayer_3_velocityY',
#  'ctPlayer_3_velocityZ',
#  'ctPlayer_3_viewX',
#  'ctPlayer_3_viewY',
#  'ctPlayer_3_hp',
#  'ctPlayer_3_armor',
#  'ctPlayer_3_activeWeapon',
#  'ctPlayer_3_isAlive',
#  'ctPlayer_3_isBlinded',
#  'ctPlayer_3_isAirborne',
#  'ctPlayer_3_isDucking',
#  'ctPlayer_3_isDuckingInProgress',
#  'ctPlayer_3_isUnDuckingInProgress',
#  'ctPlayer_3_isDefusing',
#  'ctPlayer_3_isPlanting',
#  'ctPlayer_3_isReloading',
#  'ctPlayer_3_isInBombZone',
#  'ctPlayer_3_isInBuyZone',
#  'ctPlayer_3_isStanding',
#  'ctPlayer_3_isScoped',
#  'ctPlayer_3_isWalking',
#  'ctPlayer_3_isUnknown',
#  'ctPlayer_3_SmokeGrenade',
#  'ctPlayer_3_Flashbang',
#  'ctPlayer_3_DecoyGrenade',
#  'ctPlayer_3_fireGrenades',
#  'ctPlayer_3_HEGrenade',
#  'ctPlayer_3_secondaryWeapon',
#  'ctPlayer_3_mainWeapon',
#  'ctPlayer_3_spotters',
#  'ctPlayer_3_equipmentValue',
#  'ctPlayer_3_equipmentValueFreezetimeEnd',
#  'ctPlayer_3_equipmentValueRoundStart',
#  'ctPlayer_3_cash',
#  'ctPlayer_3_cashSpendThisRound',
#  'ctPlayer_3_cashSpendTotal',
#  'ctPlayer_3_hasHelmet',
#  'ctPlayer_3_hasDefuse',
#  'ctPlayer_3_hasBomb',
#  'ctPlayer_3_ping',
#  'ctPlayer_3_zoomLevel',
#  'ctPlayer_4_ID',
#  'ctPlayer_4_x',
#  'ctPlayer_4_y',
#  'ctPlayer_4_z',
#  'ctPlayer_4_velocityX',
#  'ctPlayer_4_velocityY',
#  'ctPlayer_4_velocityZ',
#  'ctPlayer_4_viewX',
#  'ctPlayer_4_viewY',
#  'ctPlayer_4_hp',
#  'ctPlayer_4_armor',
#  'ctPlayer_4_activeWeapon',
#  'ctPlayer_4_isAlive',
#  'ctPlayer_4_isBlinded',
#  'ctPlayer_4_isAirborne',
#  'ctPlayer_4_isDucking',
#  'ctPlayer_4_isDuckingInProgress',
#  'ctPlayer_4_isUnDuckingInProgress',
#  'ctPlayer_4_isDefusing',
#  'ctPlayer_4_isPlanting',
#  'ctPlayer_4_isReloading',
#  'ctPlayer_4_isInBombZone',
#  'ctPlayer_4_isInBuyZone',
#  'ctPlayer_4_isStanding',
#  'ctPlayer_4_isScoped',
#  'ctPlayer_4_isWalking',
#  'ctPlayer_4_isUnknown',
#  'ctPlayer_4_SmokeGrenade',
#  'ctPlayer_4_Flashbang',
#  'ctPlayer_4_DecoyGrenade',
#  'ctPlayer_4_fireGrenades',
#  'ctPlayer_4_HEGrenade',
#  'ctPlayer_4_secondaryWeapon',
#  'ctPlayer_4_mainWeapon',
#  'ctPlayer_4_spotters',
#  'ctPlayer_4_equipmentValue',
#  'ctPlayer_4_equipmentValueFreezetimeEnd',
#  'ctPlayer_4_equipmentValueRoundStart',
#  'ctPlayer_4_cash',
#  'ctPlayer_4_cashSpendThisRound',
#  'ctPlayer_4_cashSpendTotal',
#  'ctPlayer_4_hasHelmet',
#  'ctPlayer_4_hasDefuse',
#  'ctPlayer_4_hasBomb',
#  'ctPlayer_4_ping',
#  'ctPlayer_4_zoomLevel',
#  'tName',
#  'tEqVal',
#  'tAlivePlayers',
#  'tTotalUtility',
#  'tPlayer_4_ID',
#  'tPlayer_4_x',
#  'tPlayer_4_y',
#  'tPlayer_4_z',
#  'tPlayer_4_velocityX',
#  'tPlayer_4_velocityY',
#  'tPlayer_4_velocityZ',
#  'tPlayer_4_viewX',
#  'tPlayer_4_viewY',
#  'tPlayer_4_hp',
#  'tPlayer_4_armor',
#  'tPlayer_4_activeWeapon',
#  'tPlayer_4_isAlive',
#  'tPlayer_4_isBlinded',
#  'tPlayer_4_isAirborne',
#  'tPlayer_4_isDucking',
#  'tPlayer_4_isDuckingInProgress',
#  'tPlayer_4_isUnDuckingInProgress',
#  'tPlayer_4_isDefusing',
#  'tPlayer_4_isPlanting',
#  'tPlayer_4_isReloading',
#  'tPlayer_4_isInBombZone',
#  'tPlayer_4_isInBuyZone',
#  'tPlayer_4_isStanding',
#  'tPlayer_4_isScoped',
#  'tPlayer_4_isWalking',
#  'tPlayer_4_isUnknown',
#  'tPlayer_4_SmokeGrenade',
#  'tPlayer_4_Flashbang',
#  'tPlayer_4_DecoyGrenade',
#  'tPlayer_4_fireGrenades',
#  'tPlayer_4_HEGrenade',
#  'tPlayer_4_secondaryWeapon',
#  'tPlayer_4_mainWeapon',
#  'tPlayer_4_spotters',
#  'tPlayer_4_equipmentValue',
#  'tPlayer_4_equipmentValueFreezetimeEnd',
#  'tPlayer_4_equipmentValueRoundStart',
#  'tPlayer_4_cash',
#  'tPlayer_4_cashSpendThisRound',
#  'tPlayer_4_cashSpendTotal',
#  'tPlayer_4_hasHelmet',
#  'tPlayer_4_hasDefuse',
#  'tPlayer_4_hasBomb',
#  'tPlayer_4_ping',
#  'tPlayer_4_zoomLevel',
#  'tPlayer_2_ID',
#  'tPlayer_2_x',
#  'tPlayer_2_y',
#  'tPlayer_2_z',
#  'tPlayer_2_velocityX',
#  'tPlayer_2_velocityY',
#  'tPlayer_2_velocityZ',
#  'tPlayer_2_viewX',
#  'tPlayer_2_viewY',
#  'tPlayer_2_hp',
#  'tPlayer_2_armor',
#  'tPlayer_2_activeWeapon',
#  'tPlayer_2_isAlive',
#  'tPlayer_2_isBlinded',
#  'tPlayer_2_isAirborne',
#  'tPlayer_2_isDucking',
#  'tPlayer_2_isDuckingInProgress',
#  'tPlayer_2_isUnDuckingInProgress',
#  'tPlayer_2_isDefusing',
#  'tPlayer_2_isPlanting',
#  'tPlayer_2_isReloading',
#  'tPlayer_2_isInBombZone',
#  'tPlayer_2_isInBuyZone',
#  'tPlayer_2_isStanding',
#  'tPlayer_2_isScoped',
#  'tPlayer_2_isWalking',
#  'tPlayer_2_isUnknown',
#  'tPlayer_2_SmokeGrenade',
#  'tPlayer_2_Flashbang',
#  'tPlayer_2_DecoyGrenade',
#  'tPlayer_2_fireGrenades',
#  'tPlayer_2_HEGrenade',
#  'tPlayer_2_secondaryWeapon',
#  'tPlayer_2_mainWeapon',
#  'tPlayer_2_spotters',
#  'tPlayer_2_equipmentValue',
#  'tPlayer_2_equipmentValueFreezetimeEnd',
#  'tPlayer_2_equipmentValueRoundStart',
#  'tPlayer_2_cash',
#  'tPlayer_2_cashSpendThisRound',
#  'tPlayer_2_cashSpendTotal',
#  'tPlayer_2_hasHelmet',
#  'tPlayer_2_hasDefuse',
#  'tPlayer_2_hasBomb',
#  'tPlayer_2_ping',
#  'tPlayer_2_zoomLevel',
#  'tPlayer_5_ID',
#  'tPlayer_5_x',
#  'tPlayer_5_y',
#  'tPlayer_5_z',
#  'tPlayer_5_velocityX',
#  'tPlayer_5_velocityY',
#  'tPlayer_5_velocityZ',
#  'tPlayer_5_viewX',
#  'tPlayer_5_viewY',
#  'tPlayer_5_hp',
#  'tPlayer_5_armor',
#  'tPlayer_5_activeWeapon',
#  'tPlayer_5_isAlive',
#  'tPlayer_5_isBlinded',
#  'tPlayer_5_isAirborne',
#  'tPlayer_5_isDucking',
#  'tPlayer_5_isDuckingInProgress',
#  'tPlayer_5_isUnDuckingInProgress',
#  'tPlayer_5_isDefusing',
#  'tPlayer_5_isPlanting',
#  'tPlayer_5_isReloading',
#  'tPlayer_5_isInBombZone',
#  'tPlayer_5_isInBuyZone',
#  'tPlayer_5_isStanding',
#  'tPlayer_5_isScoped',
#  'tPlayer_5_isWalking',
#  'tPlayer_5_isUnknown',
#  'tPlayer_5_SmokeGrenade',
#  'tPlayer_5_Flashbang',
#  'tPlayer_5_DecoyGrenade',
#  'tPlayer_5_fireGrenades',
#  'tPlayer_5_HEGrenade',
#  'tPlayer_5_secondaryWeapon',
#  'tPlayer_5_mainWeapon',
#  'tPlayer_5_spotters',
#  'tPlayer_5_equipmentValue',
#  'tPlayer_5_equipmentValueFreezetimeEnd',
#  'tPlayer_5_equipmentValueRoundStart',
#  'tPlayer_5_cash',
#  'tPlayer_5_cashSpendThisRound',
#  'tPlayer_5_cashSpendTotal',
#  'tPlayer_5_hasHelmet',
#  'tPlayer_5_hasDefuse',
#  'tPlayer_5_hasBomb',
#  'tPlayer_5_ping',
#  'tPlayer_5_zoomLevel',
#  'tPlayer_1_ID',
#  'tPlayer_1_x',
#  'tPlayer_1_y',
#  'tPlayer_1_z',
#  'tPlayer_1_velocityX',
#  'tPlayer_1_velocityY',
#  'tPlayer_1_velocityZ',
#  'tPlayer_1_viewX',
#  'tPlayer_1_viewY',
#  'tPlayer_1_hp',
#  'tPlayer_1_armor',
#  'tPlayer_1_activeWeapon',
#  'tPlayer_1_isAlive',
#  'tPlayer_1_isBlinded',
#  'tPlayer_1_isAirborne',
#  'tPlayer_1_isDucking',
#  'tPlayer_1_isDuckingInProgress',
#  'tPlayer_1_isUnDuckingInProgress',
#  'tPlayer_1_isDefusing',
#  'tPlayer_1_isPlanting',
#  'tPlayer_1_isReloading',
#  'tPlayer_1_isInBombZone',
#  'tPlayer_1_isInBuyZone',
#  'tPlayer_1_isStanding',
#  'tPlayer_1_isScoped',
#  'tPlayer_1_isWalking',
#  'tPlayer_1_isUnknown',
#  'tPlayer_1_SmokeGrenade',
#  'tPlayer_1_Flashbang',
#  'tPlayer_1_DecoyGrenade',
#  'tPlayer_1_fireGrenades',
#  'tPlayer_1_HEGrenade',
#  'tPlayer_1_secondaryWeapon',
#  'tPlayer_1_mainWeapon',
#  'tPlayer_1_spotters',
#  'tPlayer_1_equipmentValue',
#  'tPlayer_1_equipmentValueFreezetimeEnd',
#  'tPlayer_1_equipmentValueRoundStart',
#  'tPlayer_1_cash',
#  'tPlayer_1_cashSpendThisRound',
#  'tPlayer_1_cashSpendTotal',
#  'tPlayer_1_hasHelmet',
#  'tPlayer_1_hasDefuse',
#  'tPlayer_1_hasBomb',
#  'tPlayer_1_ping',
#  'tPlayer_1_zoomLevel',
#  'tPlayer_3_ID',
#  'tPlayer_3_x',
#  'tPlayer_3_y',
#  'tPlayer_3_z',
#  'tPlayer_3_velocityX',
#  'tPlayer_3_velocityY',
#  'tPlayer_3_velocityZ',
#  'tPlayer_3_viewX',
#  'tPlayer_3_viewY',
#  'tPlayer_3_hp',
#  'tPlayer_3_armor',
#  'tPlayer_3_activeWeapon',
#  'tPlayer_3_isAlive',
#  'tPlayer_3_isBlinded',
#  'tPlayer_3_isAirborne',
#  'tPlayer_3_isDucking',
#  'tPlayer_3_isDuckingInProgress',
#  'tPlayer_3_isUnDuckingInProgress',
#  'tPlayer_3_isDefusing',
#  'tPlayer_3_isPlanting',
#  'tPlayer_3_isReloading',
#  'tPlayer_3_isInBombZone',
#  'tPlayer_3_isInBuyZone',
#  'tPlayer_3_isStanding',
#  'tPlayer_3_isScoped',
#  'tPlayer_3_isWalking',
#  'tPlayer_3_isUnknown',
#  'tPlayer_3_SmokeGrenade',
#  'tPlayer_3_Flashbang',
#  'tPlayer_3_DecoyGrenade',
#  'tPlayer_3_fireGrenades',
#  'tPlayer_3_HEGrenade',
#  'tPlayer_3_secondaryWeapon',
#  'tPlayer_3_mainWeapon',
#  'tPlayer_3_spotters',
#  'tPlayer_3_equipmentValue',
#  'tPlayer_3_equipmentValueFreezetimeEnd',
#  'tPlayer_3_equipmentValueRoundStart',
#  'tPlayer_3_cash',
#  'tPlayer_3_cashSpendThisRound',
#  'tPlayer_3_cashSpendTotal',
#  'tPlayer_3_hasHelmet',
#  'tPlayer_3_hasDefuse',
#  'tPlayer_3_hasBomb',
#  'tPlayer_3_ping',
#  'tPlayer_3_zoomLevel',
#  'bombPlanted',
#  'bombsite',
#  'tick',
#  'seconds',
#  'clockTime',
#  'bomb_x',
#  'bomb_y',
#  'bomb_z',
#  'roundNum',
#  'winningSide',
#  'matchName',
#  'mapName']

# %%
def get_cols(cols, team_specific):
    team_cols = [f"{team}Player_{i}_{col}"
                     for team in ['ct', 't']
                         for i in range(1, 6)
                             for col in cols ]
    spec_cols = [f"{team}Player_{i}_{col}"
                    for team, col in team_specific
                        for i in range(1, 6)
                ]
    return team_cols + spec_cols

def get_position_columns():
    players = [f"{team}Player_{i}_{pos}"
        for team in ["ct", "t"]
            for i in range(1, 6)
                for pos in ["x", "y","z"]
    ]
    bomb = [f"bomb_{pos}" for pos in ["x", "y","z"]]
    return players + bomb

pos_cols = get_position_columns()
pos_cols
# Out:
# ['ctPlayer_1_x',
#  'ctPlayer_1_y',
#  'ctPlayer_1_z',
#  'ctPlayer_2_x',
#  'ctPlayer_2_y',
#  'ctPlayer_2_z',
#  'ctPlayer_3_x',
#  'ctPlayer_3_y',
#  'ctPlayer_3_z',
#  'ctPlayer_4_x',
#  'ctPlayer_4_y',
#  'ctPlayer_4_z',
#  'ctPlayer_5_x',
#  'ctPlayer_5_y',
#  'ctPlayer_5_z',
#  'tPlayer_1_x',
#  'tPlayer_1_y',
#  'tPlayer_1_z',
#  'tPlayer_2_x',
#  'tPlayer_2_y',
#  'tPlayer_2_z',
#  'tPlayer_3_x',
#  'tPlayer_3_y',
#  'tPlayer_3_z',
#  'tPlayer_4_x',
#  'tPlayer_4_y',
#  'tPlayer_4_z',
#  'tPlayer_5_x',
#  'tPlayer_5_y',
#  'tPlayer_5_z',
#  'bomb_x',
#  'bomb_y',
#  'bomb_z']

# %%
cols = [
    "hp", "armor", "hasHelmet", "DecoyGrenade", 
    "Flashbang", "HEGrenade", "SmokeGrenade", "fireGrenades", 
    "isBlinded"
]
add_col = ["spotters", "activeWeapon", "mainWeapon", "secondaryWeapon", "isAlive",  "ID"]
team_spec = [("ct", "hasDefuse"), ("t", "hasBomb"), ("ct", "isDefusing"), ("t", "isPlanting")]

columns = get_cols(cols + add_col, team_spec)
columns
# Out:
# ['ctPlayer_1_hp',
#  'ctPlayer_1_armor',
#  'ctPlayer_1_hasHelmet',
#  'ctPlayer_1_DecoyGrenade',
#  'ctPlayer_1_Flashbang',
#  'ctPlayer_1_HEGrenade',
#  'ctPlayer_1_SmokeGrenade',
#  'ctPlayer_1_fireGrenades',
#  'ctPlayer_1_isBlinded',
#  'ctPlayer_1_spotters',
#  'ctPlayer_1_activeWeapon',
#  'ctPlayer_1_mainWeapon',
#  'ctPlayer_1_secondaryWeapon',
#  'ctPlayer_1_isAlive',
#  'ctPlayer_1_ID',
#  'ctPlayer_2_hp',
#  'ctPlayer_2_armor',
#  'ctPlayer_2_hasHelmet',
#  'ctPlayer_2_DecoyGrenade',
#  'ctPlayer_2_Flashbang',
#  'ctPlayer_2_HEGrenade',
#  'ctPlayer_2_SmokeGrenade',
#  'ctPlayer_2_fireGrenades',
#  'ctPlayer_2_isBlinded',
#  'ctPlayer_2_spotters',
#  'ctPlayer_2_activeWeapon',
#  'ctPlayer_2_mainWeapon',
#  'ctPlayer_2_secondaryWeapon',
#  'ctPlayer_2_isAlive',
#  'ctPlayer_2_ID',
#  'ctPlayer_3_hp',
#  'ctPlayer_3_armor',
#  'ctPlayer_3_hasHelmet',
#  'ctPlayer_3_DecoyGrenade',
#  'ctPlayer_3_Flashbang',
#  'ctPlayer_3_HEGrenade',
#  'ctPlayer_3_SmokeGrenade',
#  'ctPlayer_3_fireGrenades',
#  'ctPlayer_3_isBlinded',
#  'ctPlayer_3_spotters',
#  'ctPlayer_3_activeWeapon',
#  'ctPlayer_3_mainWeapon',
#  'ctPlayer_3_secondaryWeapon',
#  'ctPlayer_3_isAlive',
#  'ctPlayer_3_ID',
#  'ctPlayer_4_hp',
#  'ctPlayer_4_armor',
#  'ctPlayer_4_hasHelmet',
#  'ctPlayer_4_DecoyGrenade',
#  'ctPlayer_4_Flashbang',
#  'ctPlayer_4_HEGrenade',
#  'ctPlayer_4_SmokeGrenade',
#  'ctPlayer_4_fireGrenades',
#  'ctPlayer_4_isBlinded',
#  'ctPlayer_4_spotters',
#  'ctPlayer_4_activeWeapon',
#  'ctPlayer_4_mainWeapon',
#  'ctPlayer_4_secondaryWeapon',
#  'ctPlayer_4_isAlive',
#  'ctPlayer_4_ID',
#  'ctPlayer_5_hp',
#  'ctPlayer_5_armor',
#  'ctPlayer_5_hasHelmet',
#  'ctPlayer_5_DecoyGrenade',
#  'ctPlayer_5_Flashbang',
#  'ctPlayer_5_HEGrenade',
#  'ctPlayer_5_SmokeGrenade',
#  'ctPlayer_5_fireGrenades',
#  'ctPlayer_5_isBlinded',
#  'ctPlayer_5_spotters',
#  'ctPlayer_5_activeWeapon',
#  'ctPlayer_5_mainWeapon',
#  'ctPlayer_5_secondaryWeapon',
#  'ctPlayer_5_isAlive',
#  'ctPlayer_5_ID',
#  'tPlayer_1_hp',
#  'tPlayer_1_armor',
#  'tPlayer_1_hasHelmet',
#  'tPlayer_1_DecoyGrenade',
#  'tPlayer_1_Flashbang',
#  'tPlayer_1_HEGrenade',
#  'tPlayer_1_SmokeGrenade',
#  'tPlayer_1_fireGrenades',
#  'tPlayer_1_isBlinded',
#  'tPlayer_1_spotters',
#  'tPlayer_1_activeWeapon',
#  'tPlayer_1_mainWeapon',
#  'tPlayer_1_secondaryWeapon',
#  'tPlayer_1_isAlive',
#  'tPlayer_1_ID',
#  'tPlayer_2_hp',
#  'tPlayer_2_armor',
#  'tPlayer_2_hasHelmet',
#  'tPlayer_2_DecoyGrenade',
#  'tPlayer_2_Flashbang',
#  'tPlayer_2_HEGrenade',
#  'tPlayer_2_SmokeGrenade',
#  'tPlayer_2_fireGrenades',
#  'tPlayer_2_isBlinded',
#  'tPlayer_2_spotters',
#  'tPlayer_2_activeWeapon',
#  'tPlayer_2_mainWeapon',
#  'tPlayer_2_secondaryWeapon',
#  'tPlayer_2_isAlive',
#  'tPlayer_2_ID',
#  'tPlayer_3_hp',
#  'tPlayer_3_armor',
#  'tPlayer_3_hasHelmet',
#  'tPlayer_3_DecoyGrenade',
#  'tPlayer_3_Flashbang',
#  'tPlayer_3_HEGrenade',
#  'tPlayer_3_SmokeGrenade',
#  'tPlayer_3_fireGrenades',
#  'tPlayer_3_isBlinded',
#  'tPlayer_3_spotters',
#  'tPlayer_3_activeWeapon',
#  'tPlayer_3_mainWeapon',
#  'tPlayer_3_secondaryWeapon',
#  'tPlayer_3_isAlive',
#  'tPlayer_3_ID',
#  'tPlayer_4_hp',
#  'tPlayer_4_armor',
#  'tPlayer_4_hasHelmet',
#  'tPlayer_4_DecoyGrenade',
#  'tPlayer_4_Flashbang',
#  'tPlayer_4_HEGrenade',
#  'tPlayer_4_SmokeGrenade',
#  'tPlayer_4_fireGrenades',
#  'tPlayer_4_isBlinded',
#  'tPlayer_4_spotters',
#  'tPlayer_4_activeWeapon',
#  'tPlayer_4_mainWeapon',
#  'tPlayer_4_secondaryWeapon',
#  'tPlayer_4_isAlive',
#  'tPlayer_4_ID',
#  'tPlayer_5_hp',
#  'tPlayer_5_armor',
#  'tPlayer_5_hasHelmet',
#  'tPlayer_5_DecoyGrenade',
#  'tPlayer_5_Flashbang',
#  'tPlayer_5_HEGrenade',
#  'tPlayer_5_SmokeGrenade',
#  'tPlayer_5_fireGrenades',
#  'tPlayer_5_isBlinded',
#  'tPlayer_5_spotters',
#  'tPlayer_5_activeWeapon',
#  'tPlayer_5_mainWeapon',
#  'tPlayer_5_secondaryWeapon',
#  'tPlayer_5_isAlive',
#  'tPlayer_5_ID',
#  'ctPlayer_1_hasDefuse',
#  'ctPlayer_2_hasDefuse',
#  'ctPlayer_3_hasDefuse',
#  'ctPlayer_4_hasDefuse',
#  'ctPlayer_5_hasDefuse',
#  'tPlayer_1_hasBomb',
#  'tPlayer_2_hasBomb',
#  'tPlayer_3_hasBomb',
#  'tPlayer_4_hasBomb',
#  'tPlayer_5_hasBomb',
#  'ctPlayer_1_isDefusing',
#  'ctPlayer_2_isDefusing',
#  'ctPlayer_3_isDefusing',
#  'ctPlayer_4_isDefusing',
#  'ctPlayer_5_isDefusing',
#  'tPlayer_1_isPlanting',
#  'tPlayer_2_isPlanting',
#  'tPlayer_3_isPlanting',
#  'tPlayer_4_isPlanting',
#  'tPlayer_5_isPlanting']

# %%
info_col = ['matchName', 'roundNum','seconds','ctAlivePlayers', 'ctEqVal', 'tAlivePlayers', 'tEqVal', 'bombsite', 'mapName']
info_col
# Out:
# ['matchName',
#  'roundNum',
#  'seconds',
#  'ctAlivePlayers',
#  'ctEqVal',
#  'tAlivePlayers',
#  'tEqVal',
#  'bombsite',
#  'mapName']

# %%
new_states = states[columns + pos_cols + info_col]
new_states.to_parquet("data/states_ESTA.parquet")
